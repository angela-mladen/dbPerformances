# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ****Load the original dataset****

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Books_rating.csv')

# %%
df
# Out:
#                  Id                           Title  Price         User_id  \
# 0        1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1        0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2        0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3        0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4        0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
# ...             ...                             ...    ...             ...
# 2999995  B000NSLVCU             The Idea of History    NaN             NaN
# 2999996  B000NSLVCU             The Idea of History    NaN  A1SMUB9ASL5L9Y
# 2999997  B000NSLVCU             The Idea of History    NaN  A2AQMEKZKK5EE4
# 2999998  B000NSLVCU             The Idea of History    NaN  A18SQGYBKS852K
# 2999999  B000NSLVCU             The Idea of History    NaN             NaN
#
# ...

# %%
print(df.dtypes)
# Out:
# Id                     object
# Title                  object
# Price                 float64
# User_id                object
# profileName            object
# review/helpfulness     object
# review/score          float64
# review/time             int64
# review/summary         object
# review/text            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Id                          0
# Title                     208
# Price                 2518829
# User_id                561787
# profileName            561905
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary            407
# review/text                 8
# dtype: int64

# %% [markdown]
# # ****Clean the dataset****

# %%
df1=df.copy()

# %% [markdown]
# Drop the null values from the columns that contain text data

# %%
df1.dropna(subset=['Title'], inplace=True)

# %%
df1.dropna(subset=['review/summary'], inplace=True)

# %%
df1.dropna(subset=['review/text'], inplace=True)

# %% [markdown]
# Fill the null values from the User_id and profileName columns with "Unknown" value

# %%
df1['User_id'].fillna('Unknown', inplace=True)
df1['profileName'].fillna('Unknown', inplace=True)

# %%
df1.isnull().sum()
# Out:
# Id                          0
# Title                       0
# Price                 2518250
# User_id                     0
# profileName                 0
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary              0
# review/text                 0
# dtype: int64

# %%
df1 = df1.dropna(subset=['Price'])

# %%
df1.shape
# Out:
# (481127, 10)

# %%
df1.isnull().sum()
# Out:
# Id                    0
# Title                 0
# Price                 0
# User_id               0
# profileName           0
# review/helpfulness    0
# review/score          0
# review/time           0
# review/summary        0
# review/text           0
# dtype: int64

# %%
contains_semicolon = df1['Title'].str.contains(';')
print(contains_semicolon.sum())
# Out:
# 1958

# %%
contains_semicolon= df1['Title'].str.contains(';')

# Drop rows where 'Title' contains ';'
df1= df1[~contains_semicolon]

print(df1)
print(contains_semicolon.sum())
# Out:
#                  Id                                              Title  Price  \
# 10       0829814000              Wonderful Worship in Smaller Churches  19.40
# 11       0829814000              Wonderful Worship in Smaller Churches  19.40
# 12       0829814000              Wonderful Worship in Smaller Churches  19.40
# 13       0829814000              Wonderful Worship in Smaller Churches  19.40
# 14       0595344550                      Whispers of the Wicked Saints  10.95
# ...             ...                                                ...    ...
# 2999953  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999988  0255364520  An End to Welfare Rights: The Rediscovery of I...  18.95
#
# ...

# %%
contains_semicolon = df1['profileName'].str.contains(';')

print(contains_semicolon.sum())
# Out:
# 1136

# %%
contains_semicolon= df1['profileName'].str.contains(';')

# Drop rows where 'Title' contains ';'
df1= df1[~contains_semicolon]

print(df1)
# Out:
#                  Id                                              Title  Price  \
# 10       0829814000              Wonderful Worship in Smaller Churches  19.40
# 11       0829814000              Wonderful Worship in Smaller Churches  19.40
# 12       0829814000              Wonderful Worship in Smaller Churches  19.40
# 13       0829814000              Wonderful Worship in Smaller Churches  19.40
# 14       0595344550                      Whispers of the Wicked Saints  10.95
# ...             ...                                                ...    ...
# 2999953  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999988  0255364520  An End to Welfare Rights: The Rediscovery of I...  18.95
#
# ...

# %%
contains_semicolon = df1['review/summary'].str.contains(';')

print(contains_semicolon.sum())
# Out:
# 6357

# %%
contains_semicolon= df1['review/summary'].str.contains(';')
#df1['review/summary'] = df1['review/summary'].str.replace(';', ' ')
# Drop rows where 'Title' contains ';'
df1= df1[~contains_semicolon]

print(df1)
# Out:
#                  Id                                              Title  Price  \
# 10       0829814000              Wonderful Worship in Smaller Churches  19.40
# 11       0829814000              Wonderful Worship in Smaller Churches  19.40
# 12       0829814000              Wonderful Worship in Smaller Churches  19.40
# 13       0829814000              Wonderful Worship in Smaller Churches  19.40
# 14       0595344550                      Whispers of the Wicked Saints  10.95
# ...             ...                                                ...    ...
# 2999953  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999988  0255364520  An End to Welfare Rights: The Rediscovery of I...  18.95
#
# ...

# %%
contains_semicolon = df1['review/text'].str.contains(';')

print(contains_semicolon.sum())
# Out:
# 85774

# %%
contains_semicolon= df1['review/text'].str.contains(';')

# Drop rows where 'Title' contains ';'
df1= df1[~contains_semicolon]

print(df1)
# Out:
#                  Id                                  Title  Price  \
# 11       0829814000  Wonderful Worship in Smaller Churches  19.40
# 12       0829814000  Wonderful Worship in Smaller Churches  19.40
# 13       0829814000  Wonderful Worship in Smaller Churches  19.40
# 15       0595344550          Whispers of the Wicked Saints  10.95
# 16       0595344550          Whispers of the Wicked Saints  10.95
# ...             ...                                    ...    ...
# 2999951  0786182431       Very Bad Deaths: Library Edition  90.00
# 2999953  0786182431       Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431       Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431       Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431       Very Bad Deaths: Library Edition  90.00
#
#                 User_id                              profileName  \
# 11       A373VVEU6Z9M0N                     Dr. Terry W. Dorsett
# ...

# %%
df1.shape
# Out:
# (385902, 10)

# %%
df1
# Out:
#                  Id                                  Title  Price  \
# 11       0829814000  Wonderful Worship in Smaller Churches  19.40
# 12       0829814000  Wonderful Worship in Smaller Churches  19.40
# 13       0829814000  Wonderful Worship in Smaller Churches  19.40
# 15       0595344550          Whispers of the Wicked Saints  10.95
# 16       0595344550          Whispers of the Wicked Saints  10.95
# ...             ...                                    ...    ...
# 2999951  0786182431       Very Bad Deaths: Library Edition  90.00
# 2999953  0786182431       Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431       Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431       Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431       Very Bad Deaths: Library Edition  90.00
#
#                 User_id                              profileName  \
# 11       A373VVEU6Z9M0N                     Dr. Terry W. Dorsett
# ...

# %%
is_duplicate = df1['Id'].duplicated().any()

if is_duplicate:
    print("The values in the 'id' column are not unique.")
else:
    print("The values in the 'id' column are unique.")
# Out:
# The values in the 'id' column are not unique.

# %%
df1['Id'] = df1['Id'] + '_' + (df1.groupby('Id').cumcount() + 1).astype(str)

# %%
is_duplicate = df1['Id'].duplicated().any()

if is_duplicate:
    print("The values in the 'id' column are not unique.")
else:
    print("The values in the 'id' column are unique.")
# Out:
# The values in the 'id' column are unique.

# %%
df1
# Out:
#                     Id                                  Title  Price  \
# 11        0829814000_1  Wonderful Worship in Smaller Churches  19.40
# 12        0829814000_2  Wonderful Worship in Smaller Churches  19.40
# 13        0829814000_3  Wonderful Worship in Smaller Churches  19.40
# 15        0595344550_1          Whispers of the Wicked Saints  10.95
# 16        0595344550_2          Whispers of the Wicked Saints  10.95
# ...                ...                                    ...    ...
# 2999951  0786182431_19       Very Bad Deaths: Library Edition  90.00
# 2999953  0786182431_20       Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431_21       Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431_22       Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431_23       Very Bad Deaths: Library Edition  90.00
#
#                 User_id                              profileName  \
# 11       A373VVEU6Z9M0N                     Dr. Terry W. Dorsett
# ...

# %%
df1.shape
# Out:
# (385902, 10)

# %%
df1['profileName'] = df1['profileName'].replace(['["“”„‟”]', "''"], ' ', regex=True)

# %%
df1['profileName'] = df1['profileName'].replace(["['‘’‛’']", ''], ' ', regex=True)

# %%
df_copy=df1.copy()

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# %%
start_date = datetime(2020, 1, 1)
end_date = datetime.now()

num_rows = len(df_copy)

random_dates = [start_date + timedelta(days=random.randint(0, (end_date - start_date).days)) for _ in range(num_rows)]

df_copy['Date'] = random_dates

print(df_copy)
# Out:
#                     Id                                  Title  Price  \
# 11        0829814000_1  Wonderful Worship in Smaller Churches  19.40
# 12        0829814000_2  Wonderful Worship in Smaller Churches  19.40
# 13        0829814000_3  Wonderful Worship in Smaller Churches  19.40
# 15        0595344550_1          Whispers of the Wicked Saints  10.95
# 16        0595344550_2          Whispers of the Wicked Saints  10.95
# ...                ...                                    ...    ...
# 2999951  0786182431_19       Very Bad Deaths: Library Edition  90.00
# 2999953  0786182431_20       Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431_21       Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431_22       Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431_23       Very Bad Deaths: Library Edition  90.00
#
#                 User_id                              profileName  \
# 11       A373VVEU6Z9M0N                     Dr. Terry W. Dorsett
# ...

# %%
df_copy
# Out:
#                     Id                                  Title  Price  \
# 11        0829814000_1  Wonderful Worship in Smaller Churches  19.40
# 12        0829814000_2  Wonderful Worship in Smaller Churches  19.40
# 13        0829814000_3  Wonderful Worship in Smaller Churches  19.40
# 15        0595344550_1          Whispers of the Wicked Saints  10.95
# 16        0595344550_2          Whispers of the Wicked Saints  10.95
# ...                ...                                    ...    ...
# 2999951  0786182431_19       Very Bad Deaths: Library Edition  90.00
# 2999953  0786182431_20       Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431_21       Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431_22       Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431_23       Very Bad Deaths: Library Edition  90.00
#
#                 User_id                              profileName  \
# 11       A373VVEU6Z9M0N                     Dr. Terry W. Dorsett
# ...

# %%
unique_titles_count = df_copy['Title'].nunique()

# Print the count of unique titles
print("Number of unique titles:", unique_titles_count)
# Out:
# Number of unique titles: 44470

# %%
df_copy.to_csv('/content/drive/MyDrive/booksRatingsFinalNew.csv',sep=';', index=False)
